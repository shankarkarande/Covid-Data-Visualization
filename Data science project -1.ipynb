# %% [markdown]
# ## 1.Importing Libraries and CSV file

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\Shankar Karande\Programming Languages\Python AI & DS\Data Science Project -1\WHO-COVID-19--GLOBAL-DATA.csv")

# %%
data.tail()
# Out:
#        Date_reported Country_code   Country WHO_region  New_cases  \
# 184381    14-02-2022           ZW  Zimbabwe       AFRO         82
# 184382    15-02-2022           ZW  Zimbabwe       AFRO        222
# 184383    16-02-2022           ZW  Zimbabwe       AFRO        260
# 184384    17-02-2022           ZW  Zimbabwe       AFRO        350
# 184385    18-02-2022           ZW  Zimbabwe       AFRO          0
#
#         Cumulative_cases  New_deaths  Cumulative_deaths
# 184381            231381           0               5374
# 184382            231603           0               5374
# 184383            231863           4               5378
# 184384            232213           1               5379
# 184385            232213           0               5379

# %%
data.columns
# Out:
# Index(['Date_reported', 'Country_code', 'Country', 'WHO_region', 'New_cases',
#        'Cumulative_cases', 'New_deaths', 'Cumulative_deaths'],
#       dtype='object')

# %%
data.describe() #descibe() function find the all operation like mean,count,mode,median.
# Out:
#           New_cases  Cumulative_cases     New_deaths  Cumulative_deaths
# count  1.843860e+05      1.843860e+05  184386.000000      184386.000000
# mean   2.270511e+03      4.977848e+05      31.760676       10432.261110
# std    1.569237e+04      2.748729e+06     166.017200       49628.839883
# min   -3.295200e+04      0.000000e+00     -60.000000           0.000000
# 25%    0.000000e+00      1.270000e+02       0.000000           1.000000
# 50%    2.100000e+01      8.438000e+03       0.000000         121.000000
# 75%    4.880000e+02      1.322770e+05       6.000000        2280.000000
# max    1.327952e+06      7.752159e+07    8786.000000      921984.000000

# %%
data.isnull().sum()
# Out:
# Date_reported          0
# Country_code         778
# Country                0
# WHO_region             0
# New_cases              0
# Cumulative_cases       0
# New_deaths             0
# Cumulative_deaths      0
# dtype: int64

# %% [markdown]
# ## 2. Relating the variable with scatterplots.

# %%
data.columns
# Out:
# Index(['Date_reported', 'Country_code', 'Country', 'WHO_region', 'New_cases',
#        'Cumulative_cases', 'New_deaths', 'Cumulative_deaths'],
#       dtype='object')

# %%
sns.relplot(x = "New_cases" , y = "New_cases" , data = data ,color = 'black')

# %%
sns.relplot(x = "New_deaths" , y = "New_deaths" , data = data ,color = 'black')

# %%
sns.relplot(x = "New_cases" , y = "New_deaths" , data = data)

# %%
sns.relplot(x = "Cumulative_cases" , y = "Cumulative_cases" , data = data,color = 'black')

# %%
sns.relplot(x = "Cumulative_deaths" , y = "Cumulative_deaths" , data = data ,color = 'black')

# %%
sns.relplot(x = "Cumulative_cases" , y = "Cumulative_deaths" , data = data)

# %%
data.columns
# Out:
# Index(['Date_reported', 'Country_code', 'Country', 'WHO_region', 'New_cases',
#        'Cumulative_cases', 'New_deaths', 'Cumulative_deaths'],
#       dtype='object')

# %%
data.WHO_region #Access specific table.
# Out:
# 0         EMRO
# 1         EMRO
# 2         EMRO
# 3         EMRO
# 4         EMRO
#           ...
# 184381    AFRO
# 184382    AFRO
# 184383    AFRO
# 184384    AFRO
# 184385    AFRO
# Name: WHO_region, Length: 184386, dtype: object

# %%
sns.pairplot(data.tail(20))

# %%
data.columns
# Out:
# Index(['Date_reported', 'Country_code', 'Country', 'WHO_region', 'New_cases',
#        'Cumulative_cases', 'New_deaths', 'Cumulative_deaths'],
#       dtype='object')

# %%
sns.catplot(x = "New_cases" , y = "New_cases" , data = data.tail(50))

# %%
sns.catplot(x = "New_deaths" , y = "New_deaths" , data = data.tail(50))
